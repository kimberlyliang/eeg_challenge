# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/eeg2025/startkit/blob/main/challenge_2.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge 2: Predicting the externalizing factor from EEG
#
# The externalizing factor is a widely recognized construct in mental health research, representing a common underlying dimension of psychopathology across various disorders.
# Currently, the externalizing factor is often assessed using self-report questionnaires or clinician ratings, which can be subjective, prone to bias, and time-consuming.
# **The Challenge 2** consists of developing a model to predict the externalizing factor from EEG recordings.
#
# The challenge encourages learning physiologically meaningful signal representations and discovery of reproducible biomarkers.
# Models of any size should emphasize robust, interpretable features that generalize across subjects,
# sessions, and acquisition sites.
#
# Unlike a standard in-distribution classification task, this regression problem stresses out-of-distribution robustness
# and extrapolation. The goal is not only to minimize error on seen subjects, but also to transfer effectively to unseen data.
#
# Ensure the dataset is available locally. If not, see the [dataset download guide](https://eeg2025.github.io/data/#downloading-the-data)

# %% [markdown]
# ## Contents of this start kit
#
# 0. Understand the externalizing factor regression task.
# 1. Loading the data.
# 2. Wrap the data into a PyTorch-compatible dataset.
# 3. Define, train and save a model.
#
# > **Note:** If you need additional explanations on the [`EEGChallengeDataset`](https://eeglab.org/EEGDash/api/eegdash.html#eegdash.EEGChallengeDataset) class, dataloading, [`braindecode`](https://braindecode.org/stable/models/models_table.html)'s deep learning models, or brain decoding in general, please refer to the start-kit of challenge 1 which delves deeper into these topics.
#
# More contents will be released during the competition inside the [`eegdash`](https://eeglab.org/EEGDash/overview.html) [examples webpage](https://eeglab.org/EEGDash/generated/auto_examples/index.html).
#
# We will establish direct communication channels with you over the next two months, resolve platform issues, and discuss other details.
#
# We are going to do weekly one-hour support time to help teams that may have difficulties with any technical aspects that may arise.
#
# We will have closer communication starting next week, 08/09/2025.
#
# Before we begin, I just want to make a deal with you, ok?
#
# This is a community competition with a strong open-source foundation. When I say open-source, I mean volunteer work.
#
# So, if you see something that does not work or could be improved, first, **please be kind**, and we will fix it together on GitHub, okay?
#
# The entire decoding community will only go further when we stop solving the same problems over and over again, and start working together.

# %% [markdown]
# ----
# | The tutorial assumes some prior knowledge of deep learning concepts and EEG concepts:|
# | --- |
# |* Standard neural network architectures, e.g., convolutional neural networks|
# |* Optimization by batch gradient descent and backpropagation|
# |* Overfitting, early stopping, regularisation |
# |* Some knowledge of pytorch and, optionally, of the pytorch Lightning framework|
# |* That you know what EEG is |
# |* That you have basic familiarity with EEG preprocessing |
# |* Like and support open-source :) |
# ----

# %%
# !pip install braindecode
# !pip install eegdash
# Out:
# Requirement already satisfied: braindecode in ./eeg_env/lib/python3.13/site-packages (1.2.0)
# Requirement already satisfied: mne>=1.10.0 in ./eeg_env/lib/python3.13/site-packages (from braindecode) (1.10.1)
# Requirement already satisfied: mne_bids>=0.16 in ./eeg_env/lib/python3.13/site-packages (from braindecode) (0.17.0)
# Requirement already satisfied: numpy in ./eeg_env/lib/python3.13/site-packages (from braindecode) (2.3.3)
# Requirement already satisfied: pandas in ./eeg_env/lib/python3.13/site-packages (from braindecode) (2.3.3)
# Requirement already satisfied: scipy in ./eeg_env/lib/python3.13/site-packages (from braindecode) (1.16.2)
# Requirement already satisfied: matplotlib in ./eeg_env/lib/python3.13/site-packages (from braindecode) (3.10.6)
# Requirement already satisfied: h5py in ./eeg_env/lib/python3.13/site-packages (from braindecode) (3.14.0)
# Requirement already satisfied: skorch>=1.2.0 in ./eeg_env/lib/python3.13/site-packages (from braindecode) (1.2.0)
# Requirement already satisfied: torch<3.0,>=2.0 in ./eeg_env/lib/python3.13/site-packages (from braindecode) (2.8.0)
# Requirement already satisfied: torchaudio<3.0,>=2.0 in ./eeg_env/lib/python3.13/site-packages (from braindecode) (2.8.0)
# Requirement already satisfied: einops in ./eeg_env/lib/python3.13/site-packages (from braindecode) (0.8.1)
# Requirement already satisfied: joblib in ./eeg_env/lib/python3.13/site-packages (from braindecode) (1.5.2)
# Requirement already satisfied: torchinfo~=1.8 in ./eeg_env/lib/python3.13/site-packages (from braindecode) (1.8.0)
# Requirement already satisfied: wfdb in ./eeg_env/lib/python3.13/site-packages (from braindecode) (4.3.0)
# Requirement already satisfied: linear_attention_transformer in ./eeg_env/lib/python3.13/site-packages (from braindecode) (0.19.1)
# Requirement already satisfied: docstring_inheritance in ./eeg_env/lib/python3.13/site-packages (from braindecode) (2.2.2)
# Requirement already satisfied: filelock in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (4.15.0)
# Requirement already satisfied: setuptools in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (1.14.0)
# Requirement already satisfied: networkx in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (3.5)
# Requirement already satisfied: jinja2 in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (3.1.6)
# Requirement already satisfied: fsspec in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode) (2025.9.0)
# Requirement already satisfied: decorator in ./eeg_env/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (5.2.1)
# Requirement already satisfied: lazy-loader>=0.3 in ./eeg_env/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (0.4)
# Requirement already satisfied: packaging in ./eeg_env/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (25.0)
# Requirement already satisfied: pooch>=1.5 in ./eeg_env/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (1.8.2)
# Requirement already satisfied: tqdm in ./eeg_env/lib/python3.13/site-packages (from mne>=1.10.0->braindecode) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in ./eeg_env/lib/python3.13/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in ./eeg_env/lib/python3.13/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode) (2.32.5)
# Requirement already satisfied: six>=1.5 in ./eeg_env/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->braindecode) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./eeg_env/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./eeg_env/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./eeg_env/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./eeg_env/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (2025.10.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in ./eeg_env/lib/python3.13/site-packages (from skorch>=1.2.0->braindecode) (1.7.2)
# Requirement already satisfied: tabulate>=0.7.7 in ./eeg_env/lib/python3.13/site-packages (from skorch>=1.2.0->braindecode) (0.9.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./eeg_env/lib/python3.13/site-packages (from scikit-learn>=0.22.0->skorch>=1.2.0->braindecode) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./eeg_env/lib/python3.13/site-packages (from sympy>=1.13.3->torch<3.0,>=2.0->braindecode) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./eeg_env/lib/python3.13/site-packages (from jinja2->torch<3.0,>=2.0->braindecode) (3.0.3)
# Requirement already satisfied: axial-positional-embedding in ./eeg_env/lib/python3.13/site-packages (from linear_attention_transformer->braindecode) (0.3.12)
# Requirement already satisfied: linformer>=0.1.0 in ./eeg_env/lib/python3.13/site-packages (from linear_attention_transformer->braindecode) (0.2.3)
# Requirement already satisfied: local-attention in ./eeg_env/lib/python3.13/site-packages (from linear_attention_transformer->braindecode) (1.11.2)
# Requirement already satisfied: product-key-memory>=0.1.5 in ./eeg_env/lib/python3.13/site-packages (from linear_attention_transformer->braindecode) (0.2.11)
# Requirement already satisfied: colt5-attention>=0.10.14 in ./eeg_env/lib/python3.13/site-packages (from product-key-memory>=0.1.5->linear_attention_transformer->braindecode) (0.11.1)
# Requirement already satisfied: hyper-connections>=0.1.8 in ./eeg_env/lib/python3.13/site-packages (from local-attention->linear_attention_transformer->braindecode) (0.2.1)
# Requirement already satisfied: pytz>=2020.1 in ./eeg_env/lib/python3.13/site-packages (from pandas->braindecode) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./eeg_env/lib/python3.13/site-packages (from pandas->braindecode) (2025.2)
# Requirement already satisfied: aiohttp>=3.10.11 in ./eeg_env/lib/python3.13/site-packages (from wfdb->braindecode) (3.13.0)
# Requirement already satisfied: soundfile>=0.10.0 in ./eeg_env/lib/python3.13/site-packages (from wfdb->braindecode) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./eeg_env/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./eeg_env/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.22.0)
# Requirement already satisfied: cffi>=1.0 in ./eeg_env/lib/python3.13/site-packages (from soundfile>=0.10.0->wfdb->braindecode) (2.0.0)
# Requirement already satisfied: pycparser in ./eeg_env/lib/python3.13/site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb->braindecode) (2.23)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: eegdash in ./eeg_env/lib/python3.13/site-packages (0.3.8)
# Requirement already satisfied: braindecode>=1.0 in ./eeg_env/lib/python3.13/site-packages (from eegdash) (1.2.0)
# Requirement already satisfied: mne_bids>=0.16.0 in ./eeg_env/lib/python3.13/site-packages (from eegdash) (0.17.0)
# Requirement already satisfied: numba in ./eeg_env/lib/python3.13/site-packages (from eegdash) (0.62.1)
# Requirement already satisfied: numpy in ./eeg_env/lib/python3.13/site-packages (from eegdash) (2.3.3)
# Requirement already satisfied: pandas in ./eeg_env/lib/python3.13/site-packages (from eegdash) (2.3.3)
# Requirement already satisfied: pybids in ./eeg_env/lib/python3.13/site-packages (from eegdash) (0.20.0)
# Requirement already satisfied: pymongo in ./eeg_env/lib/python3.13/site-packages (from eegdash) (4.15.3)
# Requirement already satisfied: python-dotenv in ./eeg_env/lib/python3.13/site-packages (from eegdash) (1.1.1)
# Requirement already satisfied: s3fs in ./eeg_env/lib/python3.13/site-packages (from eegdash) (2025.9.0)
# Requirement already satisfied: scipy in ./eeg_env/lib/python3.13/site-packages (from eegdash) (1.16.2)
# Requirement already satisfied: tqdm in ./eeg_env/lib/python3.13/site-packages (from eegdash) (4.67.1)
# Requirement already satisfied: xarray in ./eeg_env/lib/python3.13/site-packages (from eegdash) (2025.10.1)
# Requirement already satisfied: h5io>=0.2.4 in ./eeg_env/lib/python3.13/site-packages (from eegdash) (0.2.5)
# Requirement already satisfied: pymatreader in ./eeg_env/lib/python3.13/site-packages (from eegdash) (1.1.0)
# Requirement already satisfied: eeglabio in ./eeg_env/lib/python3.13/site-packages (from eegdash) (0.1.2)
# Requirement already satisfied: tabulate in ./eeg_env/lib/python3.13/site-packages (from eegdash) (0.9.0)
# Requirement already satisfied: docstring_inheritance in ./eeg_env/lib/python3.13/site-packages (from eegdash) (2.2.2)
# Requirement already satisfied: mne>=1.10.0 in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (1.10.1)
# Requirement already satisfied: matplotlib in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (3.10.6)
# Requirement already satisfied: h5py in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (3.14.0)
# Requirement already satisfied: skorch>=1.2.0 in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (1.2.0)
# Requirement already satisfied: torch<3.0,>=2.0 in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (2.8.0)
# Requirement already satisfied: torchaudio<3.0,>=2.0 in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (2.8.0)
# Requirement already satisfied: einops in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (0.8.1)
# Requirement already satisfied: joblib in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (1.5.2)
# Requirement already satisfied: torchinfo~=1.8 in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (1.8.0)
# Requirement already satisfied: wfdb in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (4.3.0)
# Requirement already satisfied: linear_attention_transformer in ./eeg_env/lib/python3.13/site-packages (from braindecode>=1.0->eegdash) (0.19.1)
# Requirement already satisfied: filelock in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (4.15.0)
# Requirement already satisfied: setuptools in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (1.14.0)
# Requirement already satisfied: networkx in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.5)
# Requirement already satisfied: jinja2 in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.1.6)
# Requirement already satisfied: fsspec in ./eeg_env/lib/python3.13/site-packages (from torch<3.0,>=2.0->braindecode>=1.0->eegdash) (2025.9.0)
# Requirement already satisfied: decorator in ./eeg_env/lib/python3.13/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (5.2.1)
# Requirement already satisfied: lazy-loader>=0.3 in ./eeg_env/lib/python3.13/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (0.4)
# Requirement already satisfied: packaging in ./eeg_env/lib/python3.13/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (25.0)
# Requirement already satisfied: pooch>=1.5 in ./eeg_env/lib/python3.13/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (1.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./eeg_env/lib/python3.13/site-packages (from matplotlib->braindecode>=1.0->eegdash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in ./eeg_env/lib/python3.13/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in ./eeg_env/lib/python3.13/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (2.32.5)
# Requirement already satisfied: six>=1.5 in ./eeg_env/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->braindecode>=1.0->eegdash) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./eeg_env/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./eeg_env/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./eeg_env/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./eeg_env/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (2025.10.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in ./eeg_env/lib/python3.13/site-packages (from skorch>=1.2.0->braindecode>=1.0->eegdash) (1.7.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./eeg_env/lib/python3.13/site-packages (from scikit-learn>=0.22.0->skorch>=1.2.0->braindecode>=1.0->eegdash) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./eeg_env/lib/python3.13/site-packages (from sympy>=1.13.3->torch<3.0,>=2.0->braindecode>=1.0->eegdash) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./eeg_env/lib/python3.13/site-packages (from jinja2->torch<3.0,>=2.0->braindecode>=1.0->eegdash) (3.0.3)
# Requirement already satisfied: axial-positional-embedding in ./eeg_env/lib/python3.13/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.3.12)
# Requirement already satisfied: linformer>=0.1.0 in ./eeg_env/lib/python3.13/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.3)
# Requirement already satisfied: local-attention in ./eeg_env/lib/python3.13/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (1.11.2)
# Requirement already satisfied: product-key-memory>=0.1.5 in ./eeg_env/lib/python3.13/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.11)
# Requirement already satisfied: colt5-attention>=0.10.14 in ./eeg_env/lib/python3.13/site-packages (from product-key-memory>=0.1.5->linear_attention_transformer->braindecode>=1.0->eegdash) (0.11.1)
# Requirement already satisfied: hyper-connections>=0.1.8 in ./eeg_env/lib/python3.13/site-packages (from local-attention->linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in ./eeg_env/lib/python3.13/site-packages (from numba->eegdash) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in ./eeg_env/lib/python3.13/site-packages (from pandas->eegdash) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./eeg_env/lib/python3.13/site-packages (from pandas->eegdash) (2025.2)
# Requirement already satisfied: nibabel>=4.0 in ./eeg_env/lib/python3.13/site-packages (from pybids->eegdash) (5.3.2)
# Requirement already satisfied: formulaic>=0.3 in ./eeg_env/lib/python3.13/site-packages (from pybids->eegdash) (1.2.1)
# Requirement already satisfied: sqlalchemy>=1.4.31 in ./eeg_env/lib/python3.13/site-packages (from pybids->eegdash) (2.0.43)
# Requirement already satisfied: bids-validator>=1.14.7 in ./eeg_env/lib/python3.13/site-packages (from pybids->eegdash) (1.14.7.post0)
# Requirement already satisfied: num2words>=0.5.10 in ./eeg_env/lib/python3.13/site-packages (from pybids->eegdash) (0.5.14)
# Requirement already satisfied: click>=8.0 in ./eeg_env/lib/python3.13/site-packages (from pybids->eegdash) (8.3.0)
# Requirement already satisfied: universal_pathlib>=0.2.2 in ./eeg_env/lib/python3.13/site-packages (from pybids->eegdash) (0.3.3)
# Requirement already satisfied: frozendict>=2.3 in ./eeg_env/lib/python3.13/site-packages (from pybids->eegdash) (2.4.6)
# Requirement already satisfied: bidsschematools>=0.10 in ./eeg_env/lib/python3.13/site-packages (from bids-validator>=1.14.7->pybids->eegdash) (1.1.0)
# Requirement already satisfied: acres in ./eeg_env/lib/python3.13/site-packages (from bidsschematools>=0.10->bids-validator>=1.14.7->pybids->eegdash) (0.5.0)
# Requirement already satisfied: pyyaml in ./eeg_env/lib/python3.13/site-packages (from bidsschematools>=0.10->bids-validator>=1.14.7->pybids->eegdash) (6.0.3)
# Requirement already satisfied: interface-meta>=1.2.0 in ./eeg_env/lib/python3.13/site-packages (from formulaic>=0.3->pybids->eegdash) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in ./eeg_env/lib/python3.13/site-packages (from formulaic>=0.3->pybids->eegdash) (2.7.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in ./eeg_env/lib/python3.13/site-packages (from formulaic>=0.3->pybids->eegdash) (1.17.3)
# Requirement already satisfied: docopt>=0.6.2 in ./eeg_env/lib/python3.13/site-packages (from num2words>=0.5.10->pybids->eegdash) (0.6.2)
# Requirement already satisfied: pathlib-abc==0.5.1 in ./eeg_env/lib/python3.13/site-packages (from universal_pathlib>=0.2.2->pybids->eegdash) (0.5.1)
# Requirement already satisfied: xmltodict in ./eeg_env/lib/python3.13/site-packages (from pymatreader->eegdash) (1.0.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./eeg_env/lib/python3.13/site-packages (from pymongo->eegdash) (2.8.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in ./eeg_env/lib/python3.13/site-packages (from s3fs->eegdash) (2.24.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./eeg_env/lib/python3.13/site-packages (from s3fs->eegdash) (3.13.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in ./eeg_env/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (0.12.0)
# Requirement already satisfied: botocore<1.40.46,>=1.40.37 in ./eeg_env/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (1.40.45)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./eeg_env/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in ./eeg_env/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (6.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./eeg_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./eeg_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.22.0)
# Requirement already satisfied: soundfile>=0.10.0 in ./eeg_env/lib/python3.13/site-packages (from wfdb->braindecode>=1.0->eegdash) (0.13.1)
# Requirement already satisfied: cffi>=1.0 in ./eeg_env/lib/python3.13/site-packages (from soundfile>=0.10.0->wfdb->braindecode>=1.0->eegdash) (2.0.0)
# Requirement already satisfied: pycparser in ./eeg_env/lib/python3.13/site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb->braindecode>=1.0->eegdash) (2.23)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from pathlib import Path
import math
import os
import random
from joblib import Parallel, delayed

import torch
from torch.utils.data import DataLoader
from torch import optim
from torch.nn.functional import l1_loss
from braindecode.preprocessing import create_fixed_length_windows
from braindecode.datasets.base import EEGWindowsDataset, BaseConcatDataset, BaseDataset
from braindecode.models import EEGNeX
from eegdash import EEGChallengeDataset

# %% [markdown]
# ⚠️ **In case of colab, before starting, make sure you're on a GPU instance for faster training!** ⚠️
#
# > If running on Google Colab, please request a GPU runtime by clicking `Runtime/Change runtime type` in the top bar menu, then selecting 'T4 GPU' under 'Hardware accelerator'.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
if device == "cuda":
    msg = "CUDA-enabled GPU found. Training should be faster."
else:
    msg = (
        "No GPU found. Training will be carried out on CPU, which might be "
        "slower.\n\nIf running on Google Colab, you can request a GPU runtime by"
        " clicking\n`Runtime/Change runtime type` in the top bar menu, then "
        "selecting 'T4 GPU'\nunder 'Hardware accelerator'."
    )
print(msg)
# Out:
# No GPU found. Training will be carried out on CPU, which might be slower.
#
# If running on Google Colab, you can request a GPU runtime by clicking
# `Runtime/Change runtime type` in the top bar menu, then selecting 'T4 GPU'
# under 'Hardware accelerator'.

# %% [markdown]
# ## 0. Understanding the externalizing factor regression task.
#
# The externalizing factor is a widely recognized construct in mental health research, representing a common underlying dimension of psychopathology across various disorders.
# Currently, the externalizing factor is often assessed using self-report questionnaires or clinician ratings, which can be subjective, prone to bias, and time-consuming.
# In the dataset of this challenge, the externalizing factor was assessed using the Child Behavior Checklist (CBCL) [McElroy et al., (2017)](https://doi.org/10.1111/jcpp.12849).
#
# The goal of Challenge 2 is to develop a model to predict the externalizing factor from EEG recordings.
# **The feasibility of using EEG data for this purpose is still an open question**.
# The solution may involve finding meaningful representations of the EEG data that correlate with the externalizing factor scores.
# The challenge encourages learning physiologically meaningful signal representations and discovery of reproducible biomarkers.
# If contestants are successful in this task, it could pave the way for more objective and efficient assessments of the externalizing factor in clinical settings.

# %% [markdown]
# ## 1. Loading the data
#
# ### A. Define local path and (down)load the data
#
# In this challenge 2 example, we load the EEG 2025 release using EEG Dash.
#
# > **Note:** in this example notebook, we load the contrast change detection task from one mini release only as an example. Naturally, you are encouraged to train your models on all complete releases, using data from all the tasks you deem relevant.

# %%
# # The first step is to define the cache folder!
# DATA_DIR = Path("~/mne_data/eeg2025_competition")

# # Creating the path if it does not exist
# DATA_DIR.mkdir(parents=True, exist_ok=True)

# # We define the list of releases to load.
# # Here, only release 5 is loaded.
# release_list = ["R5"]

# all_datasets_list = [
#     EEGChallengeDataset(
#         release=release,
#         task="contrastChangeDetection",
#         mini=True,
#         description_fields=[
#             "subject",
#             "session",
#             "run",
#             "task",
#             "age",
#             "gender",
#             "sex",
#             "p_factor",
#         ],
#         cache_dir=DATA_DIR,
#     )
#     for release in release_list
# ]
# print("Datasets loaded")
# sub_rm = ["NDARWV769JM7", "NDARME789TD2", "NDARUA442ZVF", "NDARJP304NK1",
#           "NDARTY128YLU", "NDARDW550GU6", "NDARLD243KRE", "NDARUJ292JXV", "NDARBA381JGH"]

# %%
# CORRECTED: Use your actual data directory
DATA_DIR = Path("data") 

# Check if data directory exists
if not DATA_DIR.exists():
    print(f"❌ Data directory not found: {DATA_DIR}")
    print("💡 Make sure you have downloaded the data to the data/ folder")
    raise FileNotFoundError(f"Data directory not found: {DATA_DIR}")

print(f"📁 Using data directory: {DATA_DIR.resolve()}")

# Check what releases are available
available_releases = [d.name for d in DATA_DIR.iterdir() if d.is_dir() and d.name.startswith("release_")]
print(f"📊 Available releases: {available_releases}")

# We define the list of releases to load.
# Here, only release 5 is loaded.
release_list = ["R1", "R2", "R3", "R4", "R6", "R7", "R8", "R9", "R10", "R11"]

all_datasets_list = [
    EEGChallengeDataset(
        release=release,
        task="contrastChangeDetection",
        mini=False,  # Use full dataset, not mini
        description_fields=[
            "subject",
            "session",
            "run",
            "task",
            "age",
            "gender",
            "sex",
            "p_factor",
            "externalizing",  # Add externalizing field for Challenge 2
        ],
        cache_dir=DATA_DIR,
    )
    for release in release_list
]
print("Datasets loaded")
sub_rm = ["NDARWV769JM7", "NDARME789TD2", "NDARUA442ZVF", "NDARJP304NK1",
          "NDARTY128YLU", "NDARDW550GU6", "NDARLD243KRE", "NDARUJ292JXV", "NDARBA381JGH"]
# Out:
# 📁 Using data directory: /Users/kimberly/Documents/ESE5380/eeg_challenge/data
# 📊 Available releases: ['release_8', 'release_1', 'release_6', 'release_7', 'release_9', 'release_5', 'release_2', 'release_3', 'release_4', 'release_11', 'release_10']
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /Users/kimberly/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# Datasets loaded

# %% [markdown]
# ### B. Combine the datasets into a single one
#
# Here, we combine the datasets from the different releases into a single
# ``BaseConcatDataset`` object.

# %%
# all_datasets = BaseConcatDataset(all_datasets_list)
# print(all_datasets.description)

# raws = Parallel(n_jobs=os.cpu_count())(
#     delayed(lambda d: d.raw)(d) for d in all_datasets.datasets
# )
# Out:
#            subject  run                     task      age sex  p_factor  \
# 0     NDARAC904DMU    1  contrastChangeDetection  11.3386   F    -0.603
# 1     NDARAC904DMU    3  contrastChangeDetection  11.3386   F    -0.603
# 2     NDARAC904DMU    2  contrastChangeDetection  11.3386   F    -0.603
# 3     NDARAG143ARJ    3  contrastChangeDetection   7.6648   M    -0.258
# 4     NDARAG143ARJ    1  contrastChangeDetection   7.6648   M    -0.258
# ...            ...  ...                      ...      ...  ..       ...
# 4640  NDARZV406UFK    3  contrastChangeDetection  12.0888   M    -0.390
# 4641  NDARZV406UFK    1  contrastChangeDetection  12.0888   M    -0.390
# 4642  NDARZW623WYG    2  contrastChangeDetection  11.9490   M     0.610
# 4643  NDARZW623WYG    3  contrastChangeDetection  11.9490   M     0.610
# 4644  NDARZW623WYG    1  contrastChangeDetection  11.9490   M     0.610
#
#       externalizing release_number  ehq_total commercial_use  ...  \
# 0             0.325             R1      71.17            Yes  ...
# 1             0.325             R1      71.17            Yes  ...
# 2             0.325             R1      71.17            Yes  ...
# 3             0.509             R1     100.05            Yes  ...
# 4             0.509             R1     100.05            Yes  ...
# ...             ...            ...        ...            ...  ...
# 4640          0.228            R11      93.34            Yes  ...
# 4641          0.228            R11      93.34            Yes  ...
# 4642         -0.309            R11      93.34            Yes  ...
# 4643         -0.309            R11      93.34            Yes  ...
# 4644         -0.309            R11      93.34            Yes  ...
#
#      diaryofawimpykid  contrastchangedetection_1  contrastchangedetection_2  \
# 0           available                  available                  available
# 1           available                  available                  available
# 2           available                  available                  available
# 3           available                  available                  available
# 4           available                  available                  available
# ...               ...                        ...                        ...
# 4640          caution                    caution                    caution
# 4641          caution                    caution                    caution
# 4642          caution                    caution                    caution
# 4643          caution                    caution                    caution
# 4644          caution                    caution                    caution
#
#      contrastchangedetection_3 surroundsupp_1 surroundsupp_2  \
# 0                    available      available      available
# 1                    available      available      available
# 2                    available      available      available
# 3                    available      available      available
# 4                    available      available      available
# ...                        ...            ...            ...
# 4640                   caution        caution        caution
# 4641                   caution        caution        caution
# 4642                   caution        caution        caution
# 4643                   caution        caution        caution
# 4644                   caution        caution        caution
#
#      seqlearning6target seqlearning8target symbolsearch gender
# 0           unavailable          available    available    NaN
# 1           unavailable          available    available    NaN
# 2           unavailable          available    available    NaN
# 3             available        unavailable      caution    NaN
# 4             available        unavailable      caution    NaN
# ...                 ...                ...          ...    ...
# 4640        unavailable        unavailable      caution    NaN
# 4641        unavailable        unavailable      caution    NaN
# 4642        unavailable        unavailable      caution    NaN
# 4643        unavailable        unavailable      caution    NaN
# 4644        unavailable        unavailable      caution    NaN
#
# [4645 rows x 27 columns]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.05B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.80B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.81B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.33B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.95B/s]
#
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.09B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.04B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.62B/s]]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.93B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.94B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.92B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.44B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]    | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.50B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.95B/s]
# Downloading sub-NDARAG143ARJ_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.85B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.80B/s]
# Downloading sub-NDARAN385MDH_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.80B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.47B/s]0/1.00 [00:00<?, ?B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.47B/s]1.00 [00:00<?, ?B/s]s]0 [00:00<?, ?B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.58B/s]
# Downloading sub-NDARAM704GKZ_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.45B/s]
# Downloading sub-NDARAC904DMU_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.53B/s]0<00:00, 7.39B/s]
#
# Downloading sub-NDARAC904DMU_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
# Downloading sub-NDARAN385MDH_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.31B/s]
# Downloading sub-NDARAM704GKZ_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.26B/s]:00<?, ?B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading sub-NDARAM704GKZ_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.23B/s]
# Downloading sub-NDARAC904DMU_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.55B/s]
# Downloading sub-NDARAC904DMU_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.10B/s]10B/s]
#
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.14B/s]
# Downloading sub-NDARAM704GKZ_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.39B/s]
# Downloading sub-NDARAC904DMU_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.34B/s]0<?, ?B/s]
# Downloading sub-NDARAN385MDH_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.59B/s]
# Downloading sub-NDARAG143ARJ_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.05B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.89B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.10B/s]
# Downloading sub-NDARAG143ARJ_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.59B/s]
# Downloading sub-NDARAM704GKZ_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.50B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.37B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.11B/s]
# Downloading sub-NDARAG143ARJ_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.35B/s]0<?, ?B/s]
# Downloading sub-NDARAN385MDH_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.12B/s]
# Downloading sub-NDARAG143ARJ_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.09B/s]
# Downloading sub-NDARAM704GKZ_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.51B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.05B/s]
# Downloading sub-NDARAM704GKZ_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.63B/s]0<?, ?B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.50B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.66B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.10B/s]
# Downloading sub-NDARAM704GKZ_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.71B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.15B/s]
# Downloading sub-NDARAN385MDH_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.83B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]
# Downloading sub-NDARAM704GKZ_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.58B/s]
# Downloading sub-NDARAG143ARJ_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.19B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.09B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.42B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.80B/s]
# Downloading sub-NDARAM704GKZ_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.29B/s]
# Downloading sub-NDARAG143ARJ_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.77B/s]
# Downloading sub-NDARAN385MDH_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.30B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.47B/s]
# Downloading sub-NDARAG143ARJ_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.60B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.13B/s]B/s]
# Downloading sub-NDARAC904DMU_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.67B/s]
# Downloading sub-NDARAG143ARJ_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.72B/s]
# Downloading sub-NDARAC904DMU_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.25B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.81B/s]
# Downloading sub-NDARAN385MDH_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.74B/s]
# Downloading sub-NDARAG143ARJ_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.82B/s]
# Downloading sub-NDARAG143ARJ_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.72B/s]
# Downloading sub-NDARAC904DMU_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.99B/s]:00<?, ?B/s]
# Downloading sub-NDARAC904DMU_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.48B/s]
# Downloading sub-NDARAM704GKZ_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.42B/s]
# Downloading sub-NDARAG143ARJ_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.30B/s]:00<00:00, 4.74B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.59B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.42B/s]
# Downloading sub-NDARAG143ARJ_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.85B/s]
# Downloading sub-NDARAC904DMU_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.59B/s], ?B/s]
# Downloading sub-NDARAG143ARJ_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]
# Downloading sub-NDARAC904DMU_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.62B/s]
# Downloading sub-NDARAG143ARJ_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.11B/s]
# Downloading sub-NDARAN385MDH_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.92B/s]
# Downloading sub-NDARAM704GKZ_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.77B/s], ?B/s]
# Downloading sub-NDARAC904DMU_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.60B/s], ?B/s]
# Downloading sub-NDARAG143ARJ_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.70B/s]
# Downloading sub-NDARAC904DMU_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.01B/s]
# Downloading sub-NDARAM704GKZ_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.30B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.29B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.29B/s]
# Downloading sub-NDARAC904DMU_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.47B/s]
# Downloading sub-NDARAM704GKZ_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.84B/s] ?B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.13B/s]
# Downloading sub-NDARAN385MDH_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.08B/s]
# Downloading sub-NDARAC904DMU_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.11B/s] ?B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.21B/s]
# Downloading sub-NDARAC904DMU_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.84B/s]
# Downloading sub-NDARAM704GKZ_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.26B/s] ?B/s]
# Downloading sub-NDARAG143ARJ_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.12B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.94B/s]
# Downloading sub-NDARAM704GKZ_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.53B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.75B/s]
# Downloading sub-NDARAG143ARJ_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.98B/s]
# Downloading sub-NDARAN385MDH_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.95B/s]
# Downloading sub-NDARAG143ARJ_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.71B/s]0<?, ?B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.19B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.65B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.58B/s]
# Downloading sub-NDARAC904DMU_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.05B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.29B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.28B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
# Downloading sub-NDARAN385MDH_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.15B/s]
# Downloading sub-NDARAC904DMU_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.80B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.51B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.98B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.80B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.94B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.45B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.14B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.74B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.79B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.65B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.87B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.09B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.38B/s]
#
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.03B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.25B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.08B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.61B/s]
#
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.16B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.92B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.90B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.02B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.38B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.64B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.47B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.35B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.76B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.42B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.00B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.14B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.22B/s]/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.91B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.31B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.88B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.15B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.92B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.13B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.91B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.56B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.13B/s]]]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.13B/s]]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.63B/s]]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.83B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.33B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.10B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.90B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.88B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.70B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.33B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.65B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.36B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.39B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.34B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.65B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.93B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.71B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.15B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.94B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.43B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.36B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.73B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.40B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.25B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.69B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.07B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.60B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.06B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.05B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.05B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.86B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.78B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.58B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.80B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.47B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.39B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.55B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.32B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.20B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.01B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.90B/s]<?, ?B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.93B/s] ?B/s]/s]00<?, ?B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.43B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.29B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.67B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.80B/s]
# Downloading sub-NDARAG143ARJ_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.22B/s]
# Downloading sub-NDARAG143ARJ_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.21B/s]
# Downloading sub-NDARAN385MDH_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.89B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.58B/s]B/s]
# Downloading sub-NDARAG143ARJ_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.59B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.65B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.63B/s]]s]
# Downloading sub-NDARAC904DMU_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.55B/s]
# Downloading sub-NDARAC904DMU_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.14B/s]0<?, ?B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.02B/s]
# Downloading sub-NDARAG143ARJ_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.51B/s]
# Downloading sub-NDARAG143ARJ_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.22B/s]
# Downloading sub-NDARAN385MDH_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.23B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-1_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARAG143ARJ_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.13B/s]]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.52B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.80B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.32B/s]B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.17B/s]
#
# Downloading sub-NDARAG143ARJ_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.34B/s]
# Downloading sub-NDARAN385MDH_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.82B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.14B/s]B/s]
# Downloading sub-NDARAG143ARJ_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.97B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.38B/s]
# Downloading sub-NDARAM704GKZ_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.58B/s]
# Downloading sub-NDARAM704GKZ_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.20B/s], ?B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.39B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.69B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.02B/s]
# Downloading sub-NDARAN385MDH_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.64B/s]
# Downloading sub-NDARAG143ARJ_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.62B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.15B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.07B/s]
# Downloading sub-NDARAM704GKZ_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.95B/s]
# Downloading sub-NDARAM704GKZ_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.38B/s]0<?, ?B/s]
# Downloading sub-NDARAM704GKZ_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.34B/s], ?B/s]
# Downloading sub-NDARAG143ARJ_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.12B/s]
# Downloading sub-NDARAN385MDH_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.49B/s] ?B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.30B/s]
# Downloading sub-NDARAM704GKZ_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]0<?, ?B/s]
# Downloading sub-NDARAG143ARJ_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
# Downloading sub-NDARAM704GKZ_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.44B/s]
# Downloading sub-NDARAM704GKZ_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.31B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.88B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.14B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.23B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.58B/s]
# Downloading sub-NDARAM704GKZ_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.67B/s]
# Downloading sub-NDARAM704GKZ_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.81B/s]
# Downloading sub-NDARAM704GKZ_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.63B/s]
# Downloading sub-NDARAN385MDH_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
# Downloading sub-NDARAG143ARJ_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.32B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.89B/s]
# Downloading sub-NDARAM704GKZ_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.59B/s]
# Downloading sub-NDARAC904DMU_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.88B/s]
# Downloading sub-NDARAM704GKZ_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.43B/s]
# Downloading sub-NDARAG143ARJ_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.88B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.75B/s]
# Downloading sub-NDARAG143ARJ_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.00B/s]0<?, ?B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.93B/s]
# Downloading sub-NDARAM704GKZ_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.11B/s]
# Downloading sub-NDARAC904DMU_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.08B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.49B/s]
# Downloading sub-NDARAM704GKZ_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.25B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.25B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.33B/s]
# Downloading sub-NDARAC904DMU_task-RestingState_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]0 [00:00<00:00, 6.49B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.27B/s]
# Downloading sub-NDARAM704GKZ_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.58B/s]
# Downloading sub-NDARAG143ARJ_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.57B/s]
# Downloading sub-NDARAG143ARJ_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.80B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.60B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.04B/s]
# Downloading sub-NDARAC904DMU_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.53B/s]
# Downloading sub-NDARAN385MDH_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.50B/s]
# Downloading sub-NDARAC904DMU_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.66B/s]
# Downloading sub-NDARAG143ARJ_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.09B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.98B/s]B/s]
# Downloading sub-NDARAM704GKZ_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.01B/s]
# Downloading sub-NDARAG143ARJ_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.66B/s]
# Downloading sub-NDARAG143ARJ_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.08B/s]
# Downloading sub-NDARAC904DMU_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.24B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.12B/s]
# Downloading sub-NDARAC904DMU_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.73B/s]
# Downloading sub-NDARAN385MDH_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.18B/s]
# Downloading sub-NDARAC904DMU_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.13B/s]
# Downloading sub-NDARAG143ARJ_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.66B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.41B/s]0<?, ?B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.17B/s]
# Downloading sub-NDARAG143ARJ_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.22B/s]
# Downloading sub-NDARAC904DMU_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.63B/s]
# Downloading sub-NDARAG143ARJ_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.75B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.91B/s]
# Downloading sub-NDARAC904DMU_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.32B/s]
# Downloading sub-NDARAN385MDH_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.89B/s]
# Downloading sub-NDARAC904DMU_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.11B/s]
# Downloading sub-NDARAG143ARJ_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.51B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.64B/s]| 0.00/1.00 [00:00<?, ?B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.99B/s]
# Downloading sub-NDARAC904DMU_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.54B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.89B/s]B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.05B/s]
# Downloading sub-NDARAC904DMU_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.00B/s]
# Downloading sub-NDARAN385MDH_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.39B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.11B/s]B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.81B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.42B/s]
# Downloading sub-NDARAC904DMU_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.28B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.46B/s]
# Downloading sub-NDARAC904DMU_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.74B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.66B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 10.0B/s]
# Downloading sub-NDARAC904DMU_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.60B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.81B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.73B/s]
# Downloading sub-NDARAN385MDH_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.93B/s]
# Downloading sub-NDARAC904DMU_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.75B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.92B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.59B/s]s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.68B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.48B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.56B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.88B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.80B/s]
# Downloading sub-NDARAC904DMU_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.70B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.47B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.01B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.59B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.83B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.40B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.50B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.90B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.32B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.88B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.94B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.88B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.51B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.07B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.05B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.76B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.64B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.72B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.86B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.21B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.68B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.59B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.29B/s]
#
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.46B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.85B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.75B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.59B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.69B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.11B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.99B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.67B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.40B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.74B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.16B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.03B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.96B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.72B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.14B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.73B/s]
#
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.71B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.43B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.79B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.51B/s]0<?, ?B/s] ?B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.31B/s] [00:00<?, ?B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.99B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.75B/s] [00:00<?, ?B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.14B/s]
# Downloading sub-NDARAM704GKZ_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
# Downloading sub-NDARAM704GKZ_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.64B/s]
# Downloading sub-NDARAG143ARJ_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.37B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.14B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.44B/s]
# Downloading sub-NDARAG143ARJ_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.01B/s]B/s]
# Downloading sub-NDARAG143ARJ_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.84B/s]
# Downloading sub-NDARAC904DMU_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.93B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.65B/s]B/s]
# Downloading sub-NDARAN385MDH_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.66B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.71B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.43B/s]
# Downloading sub-NDARAM704GKZ_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.84B/s]
# Downloading sub-NDARAC904DMU_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.76B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.92B/s]
# Downloading sub-NDARAC904DMU_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.64B/s], ?B/s]
# Downloading sub-NDARAC904DMU_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.37B/s]
# Downloading sub-NDARAM704GKZ_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.09B/s]
# Downloading sub-NDARAM704GKZ_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.54B/s]0<?, ?B/s]
# Downloading sub-NDARAM704GKZ_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.85B/s]
# Downloading sub-NDARAN385MDH_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.62B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.82B/s]
# Downloading sub-NDARAG143ARJ_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.36B/s]
# Downloading sub-NDARAG143ARJ_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.00B/s]
# Downloading sub-NDARAG143ARJ_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.97B/s] ?B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.12B/s]
# Downloading sub-NDARAC904DMU_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.75B/s]
# Downloading sub-NDARAM704GKZ_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.62B/s]
# Downloading sub-NDARAM704GKZ_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.32B/s]
# Downloading sub-NDARAC904DMU_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.51B/s]
# Downloading sub-NDARAM704GKZ_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.50B/s]
# Downloading sub-NDARAG143ARJ_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.77B/s]
# ...
# Downloading sub-NDARLH979WFX_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.77B/s]
# Downloading sub-NDARLH979WFX_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.27B/s]
# Downloading sub-NDARLH979WFX_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.00B/s]
# Downloading sub-NDARLH979WFX_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.35B/s]
# Downloading sub-NDARLH979WFX_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.01B/s]
# Downloading sub-NDARLH979WFX_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.26B/s]
# Downloading sub-NDARLH979WFX_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.94B/s]
# Downloading sub-NDARKU278YRR_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:34<00:00, 34.6s/B]
# Downloading sub-NDARLH979WFX_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.98B/s]
# Downloading sub-NDARLH979WFX_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.10B/s]
# Downloading sub-NDARLH979WFX_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.90B/s]
# Downloading sub-NDARLH979WFX_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.20B/s]
# Downloading sub-NDARLH979WFX_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.46B/s]
# Downloading sub-NDARLH979WFX_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.80B/s]
# Downloading sub-NDARLH979WFX_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.77B/s]
# Downloading sub-NDARLH979WFX_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.91B/s]
# Downloading sub-NDARLH979WFX_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.93B/s]
# Downloading sub-NDARLH979WFX_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.54B/s]
# Downloading sub-NDARLH979WFX_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.74B/s]
# Downloading sub-NDARLH979WFX_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.24B/s]
# Downloading sub-NDARLH979WFX_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
# Downloading sub-NDARLH979WFX_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.90B/s]
# Downloading sub-NDARKU278YRR_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [01:43<00:00, 104s/B]
# Downloading sub-NDARLH979WFX_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.19B/s]
#
# Downloading sub-NDARLH979WFX_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.04B/s]s]
# Downloading sub-NDARLH979WFX_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.02B/s]
# Downloading sub-NDARLH979WFX_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.59B/s]
# Downloading sub-NDARLH979WFX_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.63B/s]
# Downloading sub-NDARLF616PBU_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:26<00:00, 26.2s/B]
#
# Downloading sub-NDARKA627LF8_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [01:45<00:00, 106s/B]
# Downloading sub-NDARLH979WFX_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.49B/s]
#
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.98B/s]
#
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
#
# Downloading sub-NDARLL720BGU_task-seqLearning6target_events.tsv:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARKM635UY0_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [01:05<00:00, 65.9s/B]
# Downloading sub-NDARLL720BGU_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.50B/s]
#
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-3_events.tsv:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.35B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.19B/s]
#
# Downloading sub-NDARLL720BGU_task-DespicableMe_events.tsv:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.32B/s]
# Downloading sub-NDARLL720BGU_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.60B/s]
#
# Downloading sub-NDARLL720BGU_task-RestingState_events.tsv:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.50B/s]
# Downloading sub-NDARLL720BGU_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.84B/s]
#
# Downloading sub-NDARLL720BGU_task-symbolSearch_events.tsv:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.72B/s]
#
# Downloading sub-NDARLL720BGU_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.92B/s]
#
# Downloading sub-NDARLL720BGU_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.30B/s]
#
# Downloading sub-NDARLL720BGU_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.60B/s]
#
# Downloading sub-NDARLL720BGU_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
#
# Downloading sub-NDARLL720BGU_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.62B/s][A
#
# Downloading sub-NDARLL720BGU_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.83B/s]
#
# Downloading sub-NDARLL720BGU_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s] ?B/s]
#
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.45B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-2_events.tsv:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.01B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.64B/s]
#
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-3_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.83B/s]
# Downloading sub-NDARLL720BGU_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.12B/s]
#
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-2_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.56B/s]
# Downloading sub-NDARLL720BGU_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.69B/s]
#
# Downloading sub-NDARLL720BGU_task-FunwithFractals_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.64B/s]
# Downloading sub-NDARLL720BGU_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.61B/s]
#
#
# Downloading sub-NDARLL720BGU_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.76B/s]
# Downloading sub-NDARLL720BGU_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.44B/s]
#
# Downloading sub-NDARLL720BGU_task-DiaryOfAWimpyKid_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.32B/s]
#
# Downloading sub-NDARLF616PBU_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:37<00:00, 37.6s/B]
#
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-1_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 9.49B/s]
#
# Downloading sub-NDARLL720BGU_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.55B/s]
# Downloading sub-NDARLL720BGU_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.28B/s]
#
# Downloading sub-NDARLL720BGU_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.59B/s]
#
# Downloading sub-NDARLL720BGU_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.98B/s]0<?, ?B/s]
#
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.11B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.80B/s]
#
# Downloading sub-NDARLL720BGU_task-RestingState_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.84B/s]
#
#
# Downloading sub-NDARLL720BGU_task-seqLearning6target_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.39B/s]
#
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.39B/s]
#
# Downloading sub-NDARLL720BGU_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.61B/s]?, ?B/s]
#
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.34B/s]
#
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.33B/s]
#
# Downloading sub-NDARLL720BGU_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.91B/s]
#
# Downloading sub-NDARLL720BGU_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.81B/s][A
#
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.25B/s]
#
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.94B/s]B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.54B/s]
#
# Downloading sub-NDARKA627LF8_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [06:07<00:00, 368s/B][A
#
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.97B/s]
# Downloading sub-NDARLL720BGU_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.42B/s]
#
# Downloading sub-NDARLL720BGU_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.67B/s]
# Downloading sub-NDARLL720BGU_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.93B/s]
#
# Downloading sub-NDARLL720BGU_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.84B/s][A
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.28B/s]
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-2_channels.tsv:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARLL720BGU_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.69B/s]
# Downloading sub-NDARLL720BGU_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.33B/s]
# Downloading sub-NDARLL720BGU_task-ThePresent_channels.tsv:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARKM635UY0_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [02:23<00:00, 144s/B]
# Downloading sub-NDARLL720BGU_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.72B/s]
# Downloading sub-NDARLL720BGU_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.92B/s]
# Downloading sub-NDARLL720BGU_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 8.90B/s]
# Downloading sub-NDARLL720BGU_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.06B/s]B/s]
# Downloading sub-NDARLL720BGU_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.87B/s]
# Downloading sub-NDARLL720BGU_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
# Downloading sub-NDARLL720BGU_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.54B/s]
# Downloading sub-NDARLL720BGU_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.99B/s]s]
# Downloading sub-NDARLF616PBU_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:44<00:00, 44.7s/B]
# Downloading sub-NDARLH979WFX_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:14<00:00, 14.3s/B]
# Downloading sub-NDARLH979WFX_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
#
# Downloading sub-NDARLY585ZVN_task-contrastChangeDetection_run-2_events.tsv:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 all_datasets = BaseConcatDataset(all_datasets_list)
#       2 print(all_datasets.description)
# ----> 4 raws = Parallel(n_jobs=os.cpu_count())(
#       5     delayed(lambda d: d.raw)(d) for d in all_datasets.datasets
#       6 )
#
# File ~/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/Documents/ESE5380/eeg_challenge/eeg_env/lib/python3.13/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# ### C. Inspect your data
#
# We can check what is inside the dataset consuming the
# MNE-object inside the Braindecode dataset.
#
# The following snippet, if uncommented, will show the first 10 seconds of the raw EEG signal.
# We can also inspect the data further by looking at the events and annotations.
# We strongly recommend you to take a look into the details and check how the events are structured.

# %%
# raw = all_datasets.datasets[0].raw  # mne.io.Raw object
# print(raw.info)

# raw.plot(duration=10, scalings="auto", show=True)

# print(raw.annotations)

SFREQ = 100

# %% [markdown]
# ## 2. Wrap the data into a PyTorch-compatible dataset
#
# The class below defines a dataset wrapper that will extract 2-second windows,
# uniformly sampled over the whole signal. In addition, it will add useful information
# about the extracted windows, such as the externalizing factor, the subject or the task.

# %%
class DatasetWrapper(BaseDataset):
    def __init__(
        self,
        dataset: EEGWindowsDataset,
        crop_size_samples: int,
        target_name: str = "externalizing",
        seed=None,
    ):
        self.dataset = dataset
        self.crop_size_samples = crop_size_samples
        self.target_name = target_name
        self.rng = random.Random(seed)

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, index):
        X, _, crop_inds = self.dataset[index]

        target = self.dataset.description[self.target_name]
        target = float(target)

        # Additional information:
        infos = {
            "subject": self.dataset.description["subject"],
            "sex": self.dataset.description["sex"],
            "age": float(self.dataset.description["age"]),
            "task": self.dataset.description["task"],
            "session": self.dataset.description.get("session", None) or "",
            "run": self.dataset.description.get("run", None) or "",
        }

        # Randomly crop the signal to the desired length:
        i_window_in_trial, i_start, i_stop = crop_inds
        assert i_stop - i_start >= self.crop_size_samples, f"{i_stop=} {i_start=}"
        start_offset = self.rng.randint(0, i_stop - i_start - self.crop_size_samples)
        i_start = i_start + start_offset
        i_stop = i_start + self.crop_size_samples
        X = X[:, start_offset : start_offset + self.crop_size_samples]

        return X, target, (i_window_in_trial, i_start, i_stop), infos

# %% [markdown]
# We filter out certain recordings, create fixed length windows and finally make use of our `DatasetWrapper`.

# %%
# Filter out recordings that are too short
all_datasets = BaseConcatDataset(
    [
        ds
        for ds in all_datasets.datasets
        if not ds.description.subject in sub_rm
        and ds.raw.n_times >= 4 * SFREQ
        and len(ds.raw.ch_names) == 129
        and not math.isnan(ds.description["p_factor"])
    ]
)

# Create 4-seconds windows with 2-seconds stride
windows_ds = create_fixed_length_windows(
    all_datasets,
    window_size_samples=4 * SFREQ,
    window_stride_samples=2 * SFREQ,
    drop_last_window=True,
)

# Wrap each sub-dataset in the windows_ds
windows_ds = BaseConcatDataset(
    [DatasetWrapper(ds, crop_size_samples=2 * SFREQ) for ds in windows_ds.datasets]
)

# %% [markdown]
# ## 3. Define, train and save a model
#
# Now we have our pytorch dataset necessary for the training!
#
# Below, we define a simple EEGNeX model from Braindecode.
# All the braindecode models expect the input to be of shape (batch_size, n_channels, n_times)
# and have a test coverage about the behavior of the model.
# However, you can use any pytorch model you want.

# %%
# Initialize model
model = EEGNeX(n_chans=129, n_outputs=1, n_times=2 * SFREQ).to(device)

# Specify optimizer
optimizer = optim.Adamax(params=model.parameters(), lr=0.002)

print(model)

# %% [markdown]
# Finally, we can train our model. Here we define a simple training loop using pure PyTorch.
#
# > In this example, we only train for a single epoch. Feel free to increase the number of epochs.

# %%
# Create PyTorch Dataloader

num_workers = 1  # We are using a single worker, but you can increase this for faster data loading
dataloader = DataLoader(windows_ds, batch_size=128, shuffle=True, num_workers=num_workers)

n_epochs = 1

# Train model for 1 epoch
for epoch in range(n_epochs):

    for idx, batch in enumerate(dataloader):
        # Reset gradients
        optimizer.zero_grad()

        # Unpack the batch
        X, y, crop_inds, infos = batch
        X = X.to(dtype=torch.float32, device=device)
        y = y.to(dtype=torch.float32, device=device).unsqueeze(1)

        # Forward pass
        y_pred = model(X)

        # Compute loss
        loss = l1_loss(y_pred, y)
        print(f"Epoch {0} - step {idx}, loss: {loss.item()}")

        # Gradient backpropagation
        loss.backward()
        optimizer.step()

# Finally, we can save the model for later use
torch.save(model.state_dict(), "weights_challenge_2.pt")
print("Model saved as 'weights_challenge_2.pt'")
